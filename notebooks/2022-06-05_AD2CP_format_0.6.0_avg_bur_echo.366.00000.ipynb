# %%
from pathlib import Path
import numpy as np
import xarray as xr

# %%
data_path = Path("../echopype/test_data/ad2cp_output/")
file_path = data_path / "avg_bur_echo.366.00000.nc"

# %% [markdown]
# ## Top-level

# %%
xr.open_dataset(file_path)
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes:
#     conventions:                 CF-1.7, SONAR-netCDF4-1.0, ACDD-1.3
#     keywords:                    AD2CP
#     sonar_convention_authority:  ICES
#     sonar_convention_name:       SONAR-netCDF4
#     sonar_convention_version:    1.0
#     summary:
#     title:
#     date_created:                2020-12-31T18:27:48Z
#     survey_name:

# %% [markdown]
# ## Sonar group

# %%
xr.open_dataset(file_path, group="Sonar")
# Out:
# <xarray.Dataset>
# Dimensions:           (beam_group: 1)
# Coordinates:
#   * beam_group        (beam_group) object 'Beam_group1'
# Data variables:
#     beam_group_descr  (beam_group) object ...
# Attributes:
#     sonar_serial_number:
#     sonar_manufacturer:      Nortek
#     sonar_model:             AD2CP
#     sonar_software_name:
#     sonar_software_version:
#     sonar_firmware_version:  FW:2213, FPGA:172, DIGITAL:I-3, INTERFACE:H-0, A...
#     sonar_type:              acoustic Doppler current profiler (ADCP)

# %% [markdown]
# ## Beam group

# %%
ds_beam = xr.open_dataset(file_path, group="Sonar/Beam_group1")

# %%
ds_beam
# Out:
# <xarray.Dataset>
# Dimensions:                             (ping_time: 1186, ping_time_burst: 527,
#                                          beam: 4, range_sample_burst: 10,
#                                          ping_time_average: 132,
#                                          range_sample_average: 10,
#                                          ping_time_echosounder: 527,
#                                          range_sample_echosounder: 634)
# Coordinates:
#   * ping_time_average                   (ping_time_average) datetime64[ns] 20...
#   * ping_time_burst                     (ping_time_burst) datetime64[ns] 2020...
#   * ping_time_echosounder               (ping_time_echosounder) datetime64[ns] ...
#   * ping_time                           (ping_time) datetime64[ns] 2020-12-31...
#   * beam                                (beam) uint64 1 2 3 4
#   * range_sample_echosounder            (range_sample_echosounder) int64 0 .....
#   * range_sample_average                (range_sample_average) int64 0 1 ... 8 9
#   * range_sample_burst                  (range_sample_burst) int64 0 1 2 ... 8 9
# Data variables: (12/30)
#     number_of_beams                     (ping_time) uint64 ...
#     coordinate_system                   (ping_time) uint64 ...
#     number_of_cells                     (ping_time) uint64 ...
#     blanking                            (ping_time) float64 ...
#     cell_size                           (ping_time) float64 ...
#     velocity_range                      float64 ...
#     ...                                  ...
#     ast_offset_100us                    float64 ...
#     ast_pressure                        float64 ...
#     altimeter_spare                     float64 ...
#     altimeter_raw_data_num_samples      float64 ...
#     altimeter_raw_data_sample_distance  float64 ...
#     altimeter_raw_data_samples          float64 ...
# Attributes:
#     pulse_compressed:  0

# %% [markdown]
# ## Vendor group

# %%
ds_vend = xr.open_dataset(file_path, group="Vendor_specific")

# %%
ds_vend
# Out:
# <xarray.Dataset>
# Dimensions:                             (ping_time: 1186)
# Coordinates:
#   * ping_time                           (ping_time) datetime64[ns] 2020-12-31...
# Data variables: (12/29)
#     data_record_version                 (ping_time) uint8 ...
#     error                               (ping_time) uint16 ...
#     status                              (ping_time) uint32 ...
#     status0                             (ping_time) uint16 ...
#     battery_voltage                     (ping_time) float64 ...
#     power_level                         (ping_time) int8 ...
#     ...                                  ...
#     echosounder_raw_samples_i           float64 ...
#     echosounder_raw_samples_q           float64 ...
#     echosounder_raw_transmit_samples_i  float64 ...
#     echosounder_raw_transmit_samples_q  float64 ...
#     echosounder_raw_beam                float64 ...
#     echosounder_raw_echogram            float64 ...
# Attributes:
#     pulse_compressed:  0

# %% [markdown]
# ## Environment group

# %%
ds_env = xr.open_dataset(file_path, group="Environment")

# %%
ds_env
# Out:
# <xarray.Dataset>
# Dimensions:                 (ping_time: 1186)
# Coordinates:
#   * ping_time               (ping_time) datetime64[ns] 2020-12-31T18:27:53.00...
# Data variables:
#     sound_speed_indicative  (ping_time) float64 ...
#     temperature             (ping_time) float64 ...
#     pressure                (ping_time) float64 ...

# %% [markdown]
# ## Provenance group

# %%
ds_prov = xr.open_dataset(file_path, group="Provenance")

# %%
ds_prov
# Out:
# <xarray.Dataset>
# Dimensions:           (filenames: 1)
# Dimensions without coordinates: filenames
# Data variables:
#     source_filenames  (filenames) object ...
# Attributes:
#     conversion_software_name:     echopype
#     conversion_software_version:  0.6.0
#     conversion_time:              2022-06-05T16:24:12Z

# %% [markdown]
# ## Platform group

# %%
ds_plat = xr.open_dataset(file_path, group="Platform")

# %%
ds_plat
# Out:
# <xarray.Dataset>
# Dimensions:           (ping_time: 1186, xyz: 3)
# Coordinates:
#   * ping_time         (ping_time) datetime64[ns] 2020-12-31T18:27:53.00090009...
#   * xyz               (xyz) object 'x' 'y' 'z'
# Data variables:
#     heading           (ping_time) float64 ...
#     pitch             (ping_time) float64 ...
#     roll              (ping_time) float64 ...
#     magnetometer_raw  (ping_time, xyz) int16 ...
# Attributes:
#     platform_name:
#     platform_type:
#     platform_code_ICES:

# %%
list(ds_plat.variables)
# Out:
# ['heading', 'pitch', 'roll', 'magnetometer_raw', 'ping_time', 'xyz']
