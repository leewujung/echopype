# %%
import xarray as xr

# %%
xr.open_dataset("/Users/wu-jung/Downloads/Summer2017-D20170615-T190214.nc")
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes:
#     conventions:                 CF-1.7, SONAR-netCDF4-1.0, ACDD-1.3
#     keywords:                    EK60
#     sonar_convention_authority:  ICES
#     sonar_convention_name:       SONAR-netCDF4
#     sonar_convention_version:    1.0
#     summary:
#     title:
#     date_created:                2017-06-15T19:02:14Z
#     survey_name:

# %%
xr.open_dataset("/Users/wu-jung/Downloads/Summer2017-D20170615-T190214.nc", group="Sonar")
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes:
#     sonar_manufacturer:      Simrad
#     sonar_model:             ER60
#     sonar_serial_number:
#     sonar_software_name:
#     sonar_software_version:  2.4.3
#     sonar_type:              echosounder

# %%
xr.open_dataset("/Users/wu-jung/Downloads/Summer2017-D20170615-T190214.nc", group="Provenance")
# Out:
# <xarray.Dataset>
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes:
#     conversion_software_name:     echopype
#     conversion_software_version:  0.5.0
#     conversion_time:              2021-06-15T23:10:20Z
#     src_filenames:                s3://ncei-wcsd-archive/data/raw/Bell_M._Shi...

# %%
xr.open_dataset("/Users/wu-jung/Downloads/Summer2017-D20170615-T190214.nc", group="Beam")
# Out:
# <xarray.Dataset>
# Dimensions:                         (frequency: 3, ping_time: 19,
#                                      range_bin: 3888)
# Coordinates:
#   * frequency                       (frequency) float64 1.8e+04 3.8e+04 1.2e+05
#   * ping_time                       (ping_time) datetime64[ns] 2017-06-15T19:...
#   * range_bin                       (range_bin) int64 0 1 2 3 ... 3885 3886 3887
# Data variables: (12/30)
#     channel_id                      (frequency) object ...
#     beam_type                       (frequency) int64 ...
#     beamwidth_receive_alongship     (frequency) float64 ...
#     beamwidth_receive_athwartship   (frequency) float64 ...
#     beamwidth_transmit_alongship    (frequency) float64 ...
#     beamwidth_transmit_athwartship  (frequency) float64 ...
#     ...                              ...
#     data_type                       (frequency, ping_time) float64 ...
#     count                           (frequency, ping_time) float64 ...
# ...
